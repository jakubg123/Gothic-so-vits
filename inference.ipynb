# %%
character_name= "Mordrag_original"
filename = "ORG_826_MORDRAG_ATNEWCAMP_11_04.WAV"

# %%
import IPython
# IPython.display.Audio("/home/ubuntu/testowanie/out.WAV",44100)
from IPython.display import Audio, display
display(Audio(f"/home/ubuntu/infered_chars_crepe/{character_name}/{filename}", autoplay=True)) #harvest
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import IPython
# IPython.display.Audio("/home/ubuntu/testowanie/out.WAV",44100)
from IPython.display import Audio, display
display(Audio(f"/home/ubuntu/infered_chars2_crepe/{character_name}/{filename}", autoplay=True)) #crepe
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
