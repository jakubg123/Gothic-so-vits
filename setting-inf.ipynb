# %%
# !python -V
# Out:
# Python 3.10.12

# %%
# !sudo update-alternatives --install /usr/bin/python python /usr/bin/python2.7
# Out:
# 2to3	   idle3     pip3     pydoc3	 python3	 python3.10
# 2to3-3.10  idle3.10  pip3.10  pydoc3.10  python3-config  python3.10-config

# %%
# !sudo update-alternatives --install /usr/bin/python python ~/opt/python3.10.12/bin/python3.10 1

# %%
# !cp -r my_mnt_dir/KACZYNSKI ~/separated

# %% [markdown]
# !sudo update-alternatives --install /usr/bin/python python /usr/bin/python2.7 1
#
# !sudo update-alternatives --install /usr/bin/python python ~/opt/python-3.10.12/bin/python3.10 1
#
# sudo update-alternatives --config python

# %%
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
# !ls -l my_mnt_dir
# Out:
# total 32361506
# drwxr-xr-x  1 ubuntu ubuntu        4096 May  9 19:52 'Colab Notebooks'
# -rw-r--r--  1 ubuntu ubuntu   561098249 May 20 21:42  D_20.pth
# -rw-r--r--  1 ubuntu ubuntu   561098249 May 21 16:16  D_500.pth
# -rw-r--r--  1 ubuntu ubuntu   542789469 May 20 21:40  G_20.pth
# -rw-r--r--  1 ubuntu ubuntu   542789469 May 20 20:25  G_4.pth
# -rw-r--r--  1 ubuntu ubuntu   542789469 May 21 16:17  G_500.pth
# drwxr-xr-x  1 ubuntu ubuntu        4096 May 17 14:43 'Gothic Multispeaker'
# drwxr-xr-x  1 ubuntu ubuntu        4096 May 22 10:53 'Gothic Multispeaker addon'
# -rw-r--r--  1 ubuntu ubuntu   305515332 May 20 12:56 'Gothic Multispeaker.zip'
# drwxr-xr-x  1 ubuntu ubuntu        4096 May  8 13:56  Other
# drwxr-xr-x  1 ubuntu ubuntu        4096 May  8 08:50  SPEECH_COMBINED
# drwxr-xr-x  1 ubuntu ubuntu        4096 May 13 14:11  __pycache__
# drwxr-xr-x  1 ubuntu ubuntu        4096 May 22 05:56  audio_files
# ...

# %%
import IPython
# IPython.display.Audio("/home/ubuntu/testowanie/out.WAV",44100)
from IPython.display import Audio, display
# !svc infer drive/MyDrive/so-vits-svc-fork/audio/{NAME}.wav -m drive/MyDrive/so-vits-svc-fork/logs/44k/ -c drive/MyDrive/so-vits-svc-fork/logs/44k/config.json
display(Audio(f"/home/ubuntu/testowanie/out2.WAV", autoplay=True))
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import IPython
# IPython.display.Audio("/home/ubuntu/testowanie/out.WAV",44100)
from IPython.display import Audio, display
# !svc infer drive/MyDrive/so-vits-svc-fork/audio/{NAME}.wav -m drive/MyDrive/so-vits-svc-fork/logs/44k/ -c drive/MyDrive/so-vits-svc-fork/logs/44k/config.json
display(Audio(f"/home/ubuntu/testowanie/out2.WAV", autoplay=True))
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import IPython
# IPython.display.Audio("/home/ubuntu/testowanie/out.WAV",44100)import IPython
# IPython.display.Audio("/home/ubuntu/testowanie/out.WAV",44100)
from IPython.display import Audio, display
display(Audio(f"/home/ubuntu/DATA3_backup/dataset/44k/Cronos_original/INFO_CRONOS_SLEEPER_08_05.wav", autoplay=True, rate = 44100))
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !ls /home/ubuntu/all_chars/Cronos_original/INFO_CRONOS_SLEEPER_08_08.WAV
# Out:
# /home/ubuntu/all_chars/Cronos_original/INFO_CRONOS_SLEEPER_08_08.WAV

# %%
import IPython
# IPython.display.Audio("/home/ubuntu/testowanie/out.WAV",44100)
from IPython.display import Audio, display
display(Audio(f"/home/ubuntu/testowanie/out5.wav", autoplay=True))
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
